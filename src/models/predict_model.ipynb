# %% [markdown]
# ### Predict Model :
# * **Importing necessary libraries**
# * **Loading Train and Test data**
# * **Independent and Dependent variable creation**
# * **Importing trained models and predicting results**
# * **Exporting the results**
# * **User-defined Performance Ratings Prediction**

# %% [markdown]
# #### Importing necessary libraries

# %%
#Importing necessary libraries
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)
import numpy as np

# Import Trained models
import pickle

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading Train and Test data

# %%
#Loading the data
processed_file_location = 'C:/Users/User/Desktop/E10901-PR2-V18_Certified Data Scientist - Project/data/processed/'

# Files are generated from src-> Data Processing -> data_processing.ipynb
train_data = pd.read_csv(processed_file_location +'train_data.csv')
test_data = pd.read_csv(processed_file_location +'test_data.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    960 non-null    int64
#  1   Age                           960 non-null    int64
#  2   MaritalStatus                 960 non-null    object
#  3   EmpDepartment                 960 non-null    object
#  4   EmpJobRole                    960 non-null    object
#  5   BusinessTravelFrequency       960 non-null    object
#  6   DistanceFromHome              960 non-null    int64
#  7   EmpEducationLevel             960 non-null    int64
#  8   EmpEnvironmentSatisfaction    960 non-null    int64
#  9   EmpHourlyRate                 960 non-null    int64
#  10  EmpJobInvolvement             960 non-null    int64
#  11  EmpJobLevel                   960 non-null    int64
#  12  NumCompaniesWorked            960 non-null    int64
#  13  OverTime                      960 non-null    object
#  14  EmpLastSalaryHikePercent      960 non-null    int64
#  15  EmpRelationshipSatisfaction   960 non-null    int64
#  16  EmpWorkLifeBalance            960 non-null    int64
#  17  ExperienceYearsInCurrentRole  960 non-null    int64
#  18  YearsSinceLastPromotion       960 non-null    int64
#  19  Attrition                     960 non-null    object
#  20  PerformanceRating             960 non-null    int64
# dtypes: int64(15), object(6)
# memory usage: 157.6+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    240 non-null    int64
#  1   Age                           240 non-null    int64
#  2   MaritalStatus                 240 non-null    object
#  3   EmpDepartment                 240 non-null    object
#  4   EmpJobRole                    240 non-null    object
#  5   BusinessTravelFrequency       240 non-null    object
#  6   DistanceFromHome              240 non-null    int64
#  7   EmpEducationLevel             240 non-null    int64
#  8   EmpEnvironmentSatisfaction    240 non-null    int64
#  9   EmpHourlyRate                 240 non-null    int64
#  10  EmpJobInvolvement             240 non-null    int64
#  11  EmpJobLevel                   240 non-null    int64
#  12  NumCompaniesWorked            240 non-null    int64
#  13  OverTime                      240 non-null    object
#  14  EmpLastSalaryHikePercent      240 non-null    int64
#  15  EmpRelationshipSatisfaction   240 non-null    int64
#  16  EmpWorkLifeBalance            240 non-null    int64
#  17  ExperienceYearsInCurrentRole  240 non-null    int64
#  18  YearsSinceLastPromotion       240 non-null    int64
#  19  Attrition                     240 non-null    object
#  20  PerformanceRating             240 non-null    int64
# dtypes: int64(15), object(6)
# memory usage: 39.5+ KB

# %%
train_data.head()
# Out:
#    Unnamed: 0  Age MaritalStatus           EmpDepartment  \
# 0         437   28        Single                   Sales
# 1        1091   25        Single                   Sales
# 2         327   25        Single  Research & Development
# 3         576   31       Married                   Sales
# 4        1078   30       Married                   Sales
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive       Travel_Frequently                 7
# 1       Sales Executive           Travel_Rarely                 4
# 2    Research Scientist           Travel_Rarely                 1
# 3       Sales Executive           Travel_Rarely                 5
# 4  Sales Representative           Travel_Rarely                 2
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           3             55
# 1                  2                           2             99
# 2                  3                           4             40
# 3                  3                           1             51
# 4                  1                           3             72
#
#    EmpJobInvolvement  EmpJobLevel  NumCompaniesWorked OverTime  \
# 0                  3            2                   0       No
# 1                  2            2                   1      Yes
# 2                  3            1                   1       No
# 3                  3            2                   1       No
# 4                  3            1                   1       No
#
#    EmpLastSalaryHikePercent  EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                        14                            4                   3
# 1                        11                            2                   3
# 2                        18                            4                   2
# 3                        19                            3                   3
# 4                        18                            1                   3
#
#    ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition  \
# 0                             2                        1        No
# 1                             4                        1        No
# 2                             2                        2        No
# 3                             2                        0        No
# 4                             0                        0        No
#
#    PerformanceRating
# 0                  3
# 1                  2
# 2                  3
# 3                  4
# 4                  3

# %%
test_data.head()
# Out:
#    Unnamed: 0  Age MaritalStatus EmpDepartment        EmpJobRole  \
# 0         811   35       Married   Development  Business Analyst
# 1        1149   26        Single   Development         Developer
# 2         662   36       Married         Sales   Sales Executive
# 3         542   53       Married       Finance   Finance Manager
# 4         858   34      Divorced   Development  Business Analyst
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                23                  4
# 1           Travel_Rarely                24                  3
# 2           Travel_Rarely                17                  2
# 3           Travel_Rarely                24                  4
# 4           Travel_Rarely                 6                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           3             30                  3            1
# 1                           3             66                  1            1
# 2                           3             33                  2            2
# 3                           2             48                  4            3
# 4                           3             45                  2            2
#
#    NumCompaniesWorked OverTime  EmpLastSalaryHikePercent  \
# 0                   3      Yes                        15
# 1                   1      Yes                        18
# 2                   2       No                        16
# 3                   3       No                        15
# 4                   6       No                        15
#
#    EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                            3                   3
# 1                            2                   1
# 2                            3                   1
# 3                            3                   3
# 4                            3                   3
#
#    ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition  \
# 0                             2                        2        No
# 1                             0                        0       Yes
# 2                             2                        1        No
# 3                             3                        1        No
# 4                             0                        0        No
#
#    PerformanceRating
# 0                  3
# 1                  3
# 2                  2
# 3                  2
# 4                  3

# %% [markdown]
# Unnamed: 0 column is the index from the raw data, hence we can ignore that column

# %% [markdown]
# #### Independent and Dependent variable creation

# %%
X_train = train_data.iloc[:,1:-1]# Independent variable
X_test = test_data.iloc[:,1:-1] # Independent variable
y_train = train_data.PerformanceRating # Dependent variable
y_test = test_data.PerformanceRating # Dependent variable

# %%
X_train.head()
# Out:
#    Age MaritalStatus           EmpDepartment            EmpJobRole  \
# 0   28        Single                   Sales       Sales Executive
# 1   25        Single                   Sales       Sales Executive
# 2   25        Single  Research & Development    Research Scientist
# 3   31       Married                   Sales       Sales Executive
# 4   30       Married                   Sales  Sales Representative
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0       Travel_Frequently                 7                  3
# 1           Travel_Rarely                 4                  2
# 2           Travel_Rarely                 1                  3
# 3           Travel_Rarely                 5                  3
# 4           Travel_Rarely                 2                  1
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           3             55                  3            2
# 1                           2             99                  2            2
# 2                           4             40                  3            1
# 3                           1             51                  3            2
# 4                           3             72                  3            1
#
#    NumCompaniesWorked OverTime  EmpLastSalaryHikePercent  \
# 0                   0       No                        14
# 1                   1      Yes                        11
# 2                   1       No                        18
# 3                   1       No                        19
# 4                   1       No                        18
#
#    EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                            4                   3
# 1                            2                   3
# 2                            4                   2
# 3                            3                   3
# 4                            1                   3
#
#    ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition
# 0                             2                        1        No
# 1                             4                        1        No
# 2                             2                        2        No
# 3                             2                        0        No
# 4                             0                        0        No

# %%
X_test.head()
# Out:
#    Age MaritalStatus EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0   35       Married   Development  Business Analyst           Travel_Rarely
# 1   26        Single   Development         Developer           Travel_Rarely
# 2   36       Married         Sales   Sales Executive           Travel_Rarely
# 3   53       Married       Finance   Finance Manager           Travel_Rarely
# 4   34      Divorced   Development  Business Analyst           Travel_Rarely
#
#    DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0                23                  4                           3
# 1                24                  3                           3
# 2                17                  2                           3
# 3                24                  4                           2
# 4                 6                  4                           3
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  NumCompaniesWorked OverTime  \
# 0             30                  3            1                   3      Yes
# 1             66                  1            1                   1      Yes
# 2             33                  2            2                   2       No
# 3             48                  4            3                   3       No
# 4             45                  2            2                   6       No
#
#    EmpLastSalaryHikePercent  EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                        15                            3                   3
# 1                        18                            2                   1
# 2                        16                            3                   1
# 3                        15                            3                   3
# 4                        15                            3                   3
#
#    ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition
# 0                             2                        2        No
# 1                             0                        0       Yes
# 2                             2                        1        No
# 3                             3                        1        No
# 4                             0                        0        No

# %%
y_train
# Out:
# 0      3
# 1      2
# 2      3
# 3      4
# 4      3
#       ..
# 955    3
# 956    3
# 957    3
# 958    3
# 959    4
# Name: PerformanceRating, Length: 960, dtype: int64

# %%
y_test
# Out:
# 0      3
# 1      3
# 2      2
# 3      2
# 4      3
#       ..
# 235    2
# 236    3
# 237    3
# 238    3
# 239    2
# Name: PerformanceRating, Length: 240, dtype: int64

# %%
X_train.shape,X_test.shape
# Out:
# ((960, 19), (240, 19))

# %%
y_train.value_counts(),y_test.value_counts()
# Out:
# (3    699
#  2    155
#  4    106
#  Name: PerformanceRating, dtype: int64,
#  3    175
#  2     39
#  4     26
#  Name: PerformanceRating, dtype: int64)

# %% [markdown]
# #### Importing trained models and predicting results

# %%
model = ['Logistic_Regression',
         'Support Vector Classifier_1',
         'Support_Vector_Classifier_2',
         'Decision_Tree_Classifier',
         'Random_Forest_Classifier',
         'AdaBoost_Classifier',
         'Gradient_Boosting_Classifier',
         'Stacking_Classifier']

# Creating results_df dataframe to store results
train_results_df = X_train
train_results_df['Actual_PerformanceRating'] = train_data.PerformanceRating

test_results_df = X_test 
test_results_df['Actual_PerformanceRating'] = test_data.PerformanceRating

# Trained modeds are generated from src -> models -> train_model
# Predicting the results for all trained models and storing it in results_df
for i in model:
    pickled_model = pickle.load(open(processed_file_location + i + '_trained_model.pkl', 'rb'))
    train_results_df['Predicted_PerformanceRating_'+ i] = pickled_model.predict(X_train)
    test_results_df['Predicted_PerformanceRating_'+ i] = pickled_model.predict(X_test)

# %%
# Displaying the result for Training data prediction
train_results_df
# Out:
#      Age MaritalStatus           EmpDepartment             EmpJobRole  \
# 0     28        Single                   Sales        Sales Executive
# 1     25        Single                   Sales        Sales Executive
# 2     25        Single  Research & Development     Research Scientist
# 3     31       Married                   Sales        Sales Executive
# 4     30       Married                   Sales   Sales Representative
# ..   ...           ...                     ...                    ...
# 955   51        Single  Research & Development  Laboratory Technician
# 956   42       Married             Development              Developer
# 957   31       Married                   Sales   Sales Representative
# 958   33       Married             Development              Developer
# 959   37       Married  Research & Development     Research Scientist
#
#     BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0         Travel_Frequently                 7                  3
# 1             Travel_Rarely                 4                  2
# 2             Travel_Rarely                 1                  3
# 3             Travel_Rarely                 5                  3
# 4             Travel_Rarely                 2                  1
# ..                      ...               ...                ...
# 955       Travel_Frequently                 6                  2
# 956           Travel_Rarely                 2                  4
# 957           Travel_Rarely                 7                  4
# 958       Travel_Frequently                 1                  4
# 959           Travel_Rarely                 7                  4
#
#      EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# 0                             3             55                  3
# 1                             2             99                  2
# 2                             4             40                  3
# 3                             1             51                  3
# 4                             3             72                  3
# ..                          ...            ...                ...
# 955                           2             40                  2
# 956                           3             81                  3
# 957                           2             41                  2
# 958                           3             84                  4
# 959                           4             78                  3
#
#      EmpJobLevel  NumCompaniesWorked OverTime  EmpLastSalaryHikePercent  \
# 0              2                   0       No                        14
# 1              2                   1      Yes                        11
# 2              1                   1       No                        18
# 3              2                   1       No                        19
# 4              1                   1       No                        18
# ..           ...                 ...      ...                       ...
# 955            1                   0       No                        14
# 956            2                   1       No                        13
# 957            1                   3       No                        15
# 958            2                   1      Yes                        13
# 959            2                   5      Yes                        22
#
#      EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                              4                   3
# 1                              2                   3
# 2                              4                   2
# 3                              3                   3
# 4                              1                   3
# ..                           ...                 ...
# 955                            2                   2
# 956                            2                   3
# 957                            2                   4
# 958                            1                   3
# 959                            3                   3
#
#      ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition  \
# 0                               2                        1        No
# 1                               4                        1        No
# 2                               2                        2        No
# 3                               2                        0        No
# 4                               0                        0        No
# ..                            ...                      ...       ...
# 955                             0                        7        No
# 956                             2                        2        No
# 957                             7                        5        No
# 958                             5                        1        No
# 959                             3                        0        No
#
#      Actual_PerformanceRating  \
# 0                           3
# 1                           2
# 2                           3
# 3                           4
# 4                           3
# ..                        ...
# 955                         3
# 956                         3
# 957                         3
# 958                         3
# 959                         4
#
#      Predicted_PerformanceRating_Logistic_Regression  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  3
# ..                                               ...
# 955                                                2
# 956                                                3
# 957                                                2
# 958                                                3
# 959                                                4
#
#      Predicted_PerformanceRating_Support Vector Classifier_1  \
# 0                                                    3
# 1                                                    2
# 2                                                    3
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 955                                                  3
# 956                                                  3
# 957                                                  2
# 958                                                  3
# 959                                                  4
#
#      Predicted_PerformanceRating_Support_Vector_Classifier_2  \
# 0                                                    3
# 1                                                    2
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 955                                                  3
# 956                                                  3
# 957                                                  2
# 958                                                  3
# 959                                                  4
#
#      Predicted_PerformanceRating_Decision_Tree_Classifier  \
# 0                                                    3
# 1                                                    2
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 955                                                  2
# 956                                                  3
# 957                                                  3
# 958                                                  3
# 959                                                  4
#
#      Predicted_PerformanceRating_Random_Forest_Classifier  \
# 0                                                    3
# 1                                                    2
# 2                                                    3
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 955                                                  2
# 956                                                  3
# 957                                                  2
# 958                                                  3
# 959                                                  4
#
#      Predicted_PerformanceRating_AdaBoost_Classifier  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
# ..                                               ...
# 955                                                3
# 956                                                3
# 957                                                3
# 958                                                3
# 959                                                4
#
#      Predicted_PerformanceRating_Gradient_Boosting_Classifier  \
# 0                                                    3
# 1                                                    2
# 2                                                    3
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 955                                                  3
# 956                                                  3
# 957                                                  3
# 958                                                  3
# 959                                                  4
#
#      Predicted_PerformanceRating_Stacking_Classifier
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  3
# ..                                               ...
# 955                                                3
# 956                                                3
# 957                                                2
# 958                                                3
# 959                                                4
#
# [960 rows x 28 columns]

# %%
# Displaying the result for Testing data prediction
test_results_df
# Out:
#      Age MaritalStatus           EmpDepartment          EmpJobRole  \
# 0     35       Married             Development    Business Analyst
# 1     26        Single             Development           Developer
# 2     36       Married                   Sales     Sales Executive
# 3     53       Married                 Finance     Finance Manager
# 4     34      Divorced             Development    Business Analyst
# ..   ...           ...                     ...                 ...
# 235   58       Married  Research & Development         Manager R&D
# 236   30      Divorced                   Sales     Sales Executive
# 237   33        Single             Development           Developer
# 238   27        Single                   Sales     Sales Executive
# 239   40       Married  Research & Development  Senior Manager R&D
#
#     BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0             Travel_Rarely                23                  4
# 1             Travel_Rarely                24                  3
# 2             Travel_Rarely                17                  2
# 3             Travel_Rarely                24                  4
# 4             Travel_Rarely                 6                  4
# ..                      ...               ...                ...
# 235       Travel_Frequently                15                  4
# 236           Travel_Rarely                15                  2
# 237           Travel_Rarely                13                  1
# 238       Travel_Frequently                 8                  3
# 239           Travel_Rarely                20                  4
#
#      EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# 0                             3             30                  3
# 1                             3             66                  1
# 2                             3             33                  2
# 3                             2             48                  4
# 4                             3             45                  2
# ..                          ...            ...                ...
# 235                           1             87                  3
# 236                           3             94                  2
# 237                           2             53                  3
# 238                           4             37                  3
# 239                           1             61                  3
#
#      EmpJobLevel  NumCompaniesWorked OverTime  EmpLastSalaryHikePercent  \
# 0              1                   3      Yes                        15
# 1              1                   1      Yes                        18
# 2              2                   2       No                        16
# 3              3                   3       No                        15
# 4              2                   6       No                        15
# ..           ...                 ...      ...                       ...
# 235            4                   2      Yes                        14
# 236            3                   2       No                        11
# 237            1                   3       No                        18
# 238            3                   1       No                        15
# 239            3                   4       No                        20
#
#      EmpRelationshipSatisfaction  EmpWorkLifeBalance  \
# 0                              3                   3
# 1                              2                   1
# 2                              3                   1
# 3                              3                   3
# 4                              3                   3
# ..                           ...                 ...
# 235                            2                   3
# 236                            1                   3
# 237                            1                   3
# 238                            4                   3
# 239                            4                   3
#
#      ExperienceYearsInCurrentRole  YearsSinceLastPromotion Attrition  \
# 0                               2                        2        No
# 1                               0                        0       Yes
# 2                               2                        1        No
# 3                               3                        1        No
# 4                               0                        0        No
# ..                            ...                      ...       ...
# 235                             2                        2        No
# 236                             7                        1        No
# 237                             2                        0        No
# 238                             8                        1        No
# 239                            10                       11        No
#
#      Actual_PerformanceRating  \
# 0                           3
# 1                           3
# 2                           2
# 3                           2
# 4                           3
# ..                        ...
# 235                         2
# 236                         3
# 237                         3
# 238                         3
# 239                         2
#
#      Predicted_PerformanceRating_Logistic_Regression  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  3
# ..                                               ...
# 235                                                2
# 236                                                3
# 237                                                3
# 238                                                3
# 239                                                2
#
#      Predicted_PerformanceRating_Support Vector Classifier_1  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 235                                                  2
# 236                                                  3
# 237                                                  3
# 238                                                  3
# 239                                                  2
#
#      Predicted_PerformanceRating_Support_Vector_Classifier_2  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 235                                                  2
# 236                                                  3
# 237                                                  3
# 238                                                  3
# 239                                                  2
#
#      Predicted_PerformanceRating_Decision_Tree_Classifier  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 235                                                  2
# 236                                                  3
# 237                                                  3
# 238                                                  3
# 239                                                  2
#
#      Predicted_PerformanceRating_Random_Forest_Classifier  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 235                                                  2
# 236                                                  3
# 237                                                  3
# 238                                                  3
# 239                                                  2
#
#      Predicted_PerformanceRating_AdaBoost_Classifier  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
# ..                                               ...
# 235                                                3
# 236                                                3
# 237                                                3
# 238                                                3
# 239                                                3
#
#      Predicted_PerformanceRating_Gradient_Boosting_Classifier  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 235                                                  3
# 236                                                  3
# 237                                                  3
# 238                                                  3
# 239                                                  2
#
#      Predicted_PerformanceRating_Stacking_Classifier
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  3
# ..                                               ...
# 235                                                2
# 236                                                3
# 237                                                3
# 238                                                3
# 239                                                2
#
# [240 rows x 28 columns]

# %% [markdown]
# #### Exporting the results

# %%
train_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 28 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Age                                                       960 non-null    int64
#  1   MaritalStatus                                             960 non-null    object
#  2   EmpDepartment                                             960 non-null    object
#  3   EmpJobRole                                                960 non-null    object
#  4   BusinessTravelFrequency                                   960 non-null    object
#  5   DistanceFromHome                                          960 non-null    int64
#  6   EmpEducationLevel                                         960 non-null    int64
#  7   EmpEnvironmentSatisfaction                                960 non-null    int64
#  8   EmpHourlyRate                                             960 non-null    int64
#  9   EmpJobInvolvement                                         960 non-null    int64
#  10  EmpJobLevel                                               960 non-null    int64
#  11  NumCompaniesWorked                                        960 non-null    int64
#  12  OverTime                                                  960 non-null    object
#  13  EmpLastSalaryHikePercent                                  960 non-null    int64
#  14  EmpRelationshipSatisfaction                               960 non-null    int64
#  15  EmpWorkLifeBalance                                        960 non-null    int64
#  16  ExperienceYearsInCurrentRole                              960 non-null    int64
#  17  YearsSinceLastPromotion                                   960 non-null    int64
#  18  Attrition                                                 960 non-null    object
#  19  Actual_PerformanceRating                                  960 non-null    int64
#  20  Predicted_PerformanceRating_Logistic_Regression           960 non-null    int64
#  21  Predicted_PerformanceRating_Support Vector Classifier_1   960 non-null    int64
#  22  Predicted_PerformanceRating_Support_Vector_Classifier_2   960 non-null    int64
#  23  Predicted_PerformanceRating_Decision_Tree_Classifier      960 non-null    int64
#  24  Predicted_PerformanceRating_Random_Forest_Classifier      960 non-null    int64
#  25  Predicted_PerformanceRating_AdaBoost_Classifier           960 non-null    int64
#  26  Predicted_PerformanceRating_Gradient_Boosting_Classifier  960 non-null    int64
#  27  Predicted_PerformanceRating_Stacking_Classifier           960 non-null    int64
# dtypes: int64(22), object(6)
# memory usage: 210.1+ KB

# %%
test_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 28 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Age                                                       240 non-null    int64
#  1   MaritalStatus                                             240 non-null    object
#  2   EmpDepartment                                             240 non-null    object
#  3   EmpJobRole                                                240 non-null    object
#  4   BusinessTravelFrequency                                   240 non-null    object
#  5   DistanceFromHome                                          240 non-null    int64
#  6   EmpEducationLevel                                         240 non-null    int64
#  7   EmpEnvironmentSatisfaction                                240 non-null    int64
#  8   EmpHourlyRate                                             240 non-null    int64
#  9   EmpJobInvolvement                                         240 non-null    int64
#  10  EmpJobLevel                                               240 non-null    int64
#  11  NumCompaniesWorked                                        240 non-null    int64
#  12  OverTime                                                  240 non-null    object
#  13  EmpLastSalaryHikePercent                                  240 non-null    int64
#  14  EmpRelationshipSatisfaction                               240 non-null    int64
#  15  EmpWorkLifeBalance                                        240 non-null    int64
#  16  ExperienceYearsInCurrentRole                              240 non-null    int64
#  17  YearsSinceLastPromotion                                   240 non-null    int64
#  18  Attrition                                                 240 non-null    object
#  19  Actual_PerformanceRating                                  240 non-null    int64
#  20  Predicted_PerformanceRating_Logistic_Regression           240 non-null    int64
#  21  Predicted_PerformanceRating_Support Vector Classifier_1   240 non-null    int64
#  22  Predicted_PerformanceRating_Support_Vector_Classifier_2   240 non-null    int64
#  23  Predicted_PerformanceRating_Decision_Tree_Classifier      240 non-null    int64
#  24  Predicted_PerformanceRating_Random_Forest_Classifier      240 non-null    int64
#  25  Predicted_PerformanceRating_AdaBoost_Classifier           240 non-null    int64
#  26  Predicted_PerformanceRating_Gradient_Boosting_Classifier  240 non-null    int64
#  27  Predicted_PerformanceRating_Stacking_Classifier           240 non-null    int64
# dtypes: int64(22), object(6)
# memory usage: 52.6+ KB

# %%
# Exporting the results
train_results_df.to_csv(processed_file_location + 'train_data_with_predicted_results.csv')
test_results_df.to_csv(processed_file_location + 'test_data_with_predicted_results.csv')

# %% [markdown]
# #### User-defined Performance Ratings Prediction

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           240 non-null    int64
#  1   MaritalStatus                 240 non-null    object
#  2   EmpDepartment                 240 non-null    object
#  3   EmpJobRole                    240 non-null    object
#  4   BusinessTravelFrequency       240 non-null    object
#  5   DistanceFromHome              240 non-null    int64
#  6   EmpEducationLevel             240 non-null    int64
#  7   EmpEnvironmentSatisfaction    240 non-null    int64
#  8   EmpHourlyRate                 240 non-null    int64
#  9   EmpJobInvolvement             240 non-null    int64
#  10  EmpJobLevel                   240 non-null    int64
#  11  NumCompaniesWorked            240 non-null    int64
#  12  OverTime                      240 non-null    object
#  13  EmpLastSalaryHikePercent      240 non-null    int64
#  14  EmpRelationshipSatisfaction   240 non-null    int64
#  15  EmpWorkLifeBalance            240 non-null    int64
#  16  ExperienceYearsInCurrentRole  240 non-null    int64
#  17  YearsSinceLastPromotion       240 non-null    int64
#  18  Attrition                     240 non-null    object
# dtypes: int64(13), object(6)
# memory usage: 35.8+ KB

# %%
# Provide appropiate data to predict the performance rating
input_data = []
input_data.append(int(input('Age : '))) 
print('\nMaritalStatus can be Single / Married / Divorced')
input_data.append(str(input('MaritalStatus  : '))) 
print('\nEmpDepartment can be Sales / Human Resources / Development / Data Science / Research & Development / Finance')
input_data.append(str(input('EmpDepartment  : ')))
print('\nEmpJobRole can be\nSales Executive / Manager / Developer / Sales Representative / Human Resources / \
Senior Developer / Data Scientist / Senior Manager R&D / Laboratory Technician / Manufacturing Director /\
Research Scientist / Healthcare Representative / Research Director / Manager R&D / Finance Manager /\
Technical Architect / Business Analyst / Technical Lead / Delivery Manager') 
input_data.append(str(input('EmpJobRole  : ')))
print('\nBusinessTravelFrequency can be Travel_Rarely / Travel_Frequently / Non-Travel')
input_data.append(str(input('BusinessTravelFrequency  : ')))
input_data.append(int(input('DistanceFromHome  : '))) 
input_data.append(int(input('EmpEducationLevel [1-5] : ')))
input_data.append(int(input('EmpEnvironmentSatisfaction [1-4]  : '))) 
input_data.append(int(input('EmpHourlyRate  : '))) 
input_data.append(int(input('EmpJobInvolvement [1-4] : ')))
input_data.append(int(input('EmpJobLevel [1-5] : '))) 
input_data.append(int(input('NumCompaniesWorked  : '))) 
input_data.append(str(input('OverTime  [Yes / No] : ')))
input_data.append(int(input('EmpLastSalaryHikePercent  : '))) 
input_data.append(int(input('EmpRelationshipSatisfaction [1-4] : ')))
input_data.append(int(input('EmpWorkLifeBalance [1-4] : '))) 
input_data.append(int(input('ExperienceYearsInCurrentRole  : ')))
input_data.append(int(input('YearsSinceLastPromotion  : '))) 
input_data.append(str(input('Attrition [Yes / No] : ')))
print('\n\n\n')

# Converting required features to be integers to predict the performance rating
input_df =pd.DataFrame(np.array(input_data).reshape(1,19),columns = X_test.columns)
for col in X_test.describe().columns:
    input_df[col] = input_df[col].astype('int')

# Predicting the results for all trained models and storing it in results_df
for i in model:
    pickled_model = pickle.load(open(processed_file_location + i + '_trained_model.pkl', 'rb'))
    print(f'{i} predicted PerformanceRating : {int(pickled_model.predict(input_df))}')
# Out:
# Age : 26
#
# MaritalStatus can be Single / Married / Divorced
# MaritalStatus  : Single
#
# EmpDepartment can be Sales / Human Resources / Development / Data Science / Research & Development / Finance
# EmpDepartment  : Sales
#
# EmpJobRole can be
# Sales Executive / Manager / Developer / Sales Representative / Human Resources / Senior Developer / Data Scientist / Senior Manager R&D / Laboratory Technician / Manufacturing Director /Research Scientist / Healthcare Representative / Research Director / Manager R&D / Finance Manager /Technical Architect / Business Analyst / Technical Lead / Delivery Manager
# EmpJobRole  : Manager
#
# BusinessTravelFrequency can be Travel_Rarely / Travel_Frequently / Non-Travel
# BusinessTravelFrequency  : Travel_Rarely
# DistanceFromHome  : 20
# EmpEducationLevel [1-5] : 3
# EmpEnvironmentSatisfaction [1-4]  : 2
# EmpHourlyRate  : 25
# EmpJobInvolvement [1-4] : 2
# EmpJobLevel [1-5] : 3
# NumCompaniesWorked  : 7
# OverTime  [Yes / No] : Yes
# EmpLastSalaryHikePercent  : 14
# EmpRelationshipSatisfaction [1-4] : 3
# EmpWorkLifeBalance [1-4] : 2
# ExperienceYearsInCurrentRole  : 5
# YearsSinceLastPromotion  : 4
# Attrition [Yes / No] : No
#
#
#
#
# Logistic_Regression predicted PerformanceRating : 2
# Support Vector Classifier_1 predicted PerformanceRating : 2
# Support_Vector_Classifier_2 predicted PerformanceRating : 2
# Decision_Tree_Classifier predicted PerformanceRating : 2
# Random_Forest_Classifier predicted PerformanceRating : 2
# AdaBoost_Classifier predicted PerformanceRating : 2
# Gradient_Boosting_Classifier predicted PerformanceRating : 2
# Stacking_Classifier predicted PerformanceRating : 2

# %% [markdown]
# ### Summary

# %% [markdown]
# **Importing necessary libraries**
# * pandas
# * numpy
# * pickle to import trained models in the processed folder.
#
# **Loading Train and Test data**
# * Train data and Test data are loaded from file location data-> processed -> train_data.csv,test_data.csv
#
# **Independent and Dependent variable creation**
# * Creating X_train and X_test as independent variable and y_train and y_test as dependent variable
#
# **Importing trained models and predicting results**
# * Below Models are imported using pickle from ile location data-> processed -> *_trained_model.pkl
# 	* Logistic_Regression,
# 	* Support Vector Classifier_1
# 	* Support_Vector_Classifier_2
# 	* Decision_Tree_Classifier
# 	* Random_Forest_Classifier
# 	* AdaBoost_Classifier
# 	* Gradient_Boosting_Classifier
# 	* Stacking_Classifier (LogisticRegression + SVC + RandomForestClassifier)
# * Predicting the results for all trained models for both X_train and X_test and storing the results in dataframes.
#
# **Exporting the results**
# * Both Train results and Test results are exported to processed folder using pickle.
#
# **User-defined Performance Ratings Prediction**
# * Get the input from the user and results are predicted using all trained models in processed folder.
